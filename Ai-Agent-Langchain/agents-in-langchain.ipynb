# %%
from langchain_groq import ChatGroq
from langchain_core.tools import tool
import os 
from dotenv import load_dotenv
import requests
load_dotenv(override=True)

# Load environment variables from .env file
load_dotenv()

# Retrieve API key from environment
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# Initialize Groq Chat Model
llm = ChatGroq(
    model="llama-3.1-8b-instant"
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain_groq import ChatGroq
#       2 from langchain_core.tools import tool
#       3 import os
#
# File e:\Projects\Project1Demo\Langchain_Modules_Learning_Series\.venv\Lib\site-packages\langchain_groq\__init__.py:3
#       1 """Groq integration for LangChain."""
# ----> 3 from langchain_groq.chat_models import ChatGroq
#       4 from langchain_groq.version import __version__
#       6 __all__ = ["ChatGroq", "__version__"]
#
# File e:\Projects\Project1Demo\Langchain_Modules_Learning_Series\.venv\Lib\site-packages\langchain_groq\chat_models.py:11
#       8 from operator import itemgetter
#       9 from typing import Any, Literal, cast
# ---> 11 from langchain_core.callbacks import (
#      12     AsyncCallbackManagerForLLMRun,
#      13     CallbackManagerForLLMRun,
#      14 )
#      15 from langchain_core.language_models import (
#      16     LanguageModelInput,
#      17     ModelProfile,
#      18     ModelProfileRegistry,
#      19 )
#      20 from langchain_core.language_models.chat_models import (
#      21     BaseChatModel,
#      22     LangSmithParams,
#      23     agenerate_from_stream,
#      24     generate_from_stream,
#      25 )
#
# File e:\Projects\Project1Demo\Langchain_Modules_Learning_Series\.venv\Lib\site-packages\langchain_core\__init__.py:11
#       1 """`langchain-core` defines the base abstractions for the LangChain ecosystem.
#       2
#       3 The interfaces for core components like chat models, LLMs, vector stores, retrievers,
#    (...)      8 very lightweight.
#       9 """
# ---> 11 from langchain_core._api import (
#      12     surface_langchain_beta_warnings,
#      13     surface_langchain_deprecation_warnings,
#      14 )
#      15 from langchain_core.version import VERSION
#      17 __version__ = VERSION
#
# File e:\Projects\Project1Demo\Langchain_Modules_Learning_Series\.venv\Lib\site-packages\langchain_core\_api\__init__.py:76, in __getattr__(attr_name)
#      61 """Dynamically import and return an attribute from a submodule.
#      62
#      63 This function enables lazy loading of API functions from submodules, reducing
#    (...)     73     AttributeError: If the attribute is not a valid dynamic import.
#      74 """
#      75 module_name = _dynamic_imports.get(attr_name)
# ---> 76 result = import_attr(attr_name, module_name, __spec__.parent)
#      77 globals()[attr_name] = result
#      78 return result
#
# File e:\Projects\Project1Demo\Langchain_Modules_Learning_Series\.venv\Lib\site-packages\langchain_core\_import_utils.py:36, in import_attr(attr_name, module_name, package)
#      34 else:
#      35     try:
# ---> 36         module = import_module(f".{module_name}", package=package)
#      37     except ModuleNotFoundError as err:
#      38         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File e:\Projects\Project1Demo\Langchain_Modules_Learning_Series\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:24
#      16 from collections.abc import Callable, Generator
#      17 from typing import (
#      18     Any,
#      19     ParamSpec,
#      20     TypeVar,
#      21     cast,
#      22 )
# ---> 24 from pydantic.fields import FieldInfo
#      25 from pydantic.v1.fields import FieldInfo as FieldInfoV1
#      27 from langchain_core._api.internal import is_caller_internal
#
# File e:\Projects\Project1Demo\Langchain_Modules_Learning_Series\.venv\Lib\site-packages\pydantic\__init__.py:5
#       2 from typing import TYPE_CHECKING
#       3 from warnings import warn
# ----> 5 from ._migration import getattr_migration
#       6 from .version import VERSION, _ensure_pydantic_core_version
#       8 _ensure_pydantic_core_version()
#
# File e:\Projects\Project1Demo\Langchain_Modules_Learning_Series\.venv\Lib\site-packages\pydantic\_migration.py:4
#       1 import sys
#       2 from typing import Any, Callable
# ----> 4 from pydantic.warnings import PydanticDeprecatedSince20
#       6 from .version import version_short
#       8 MOVED_IN_V2 = {
#       9     'pydantic.utils:version_info': 'pydantic.version:version_info',
#      10     'pydantic.error_wrappers:ValidationError': 'pydantic:ValidationError',
#    (...)     15     'pydantic.generics:GenericModel': 'pydantic.BaseModel',
#      16 }
#
# File e:\Projects\Project1Demo\Langchain_Modules_Learning_Series\.venv\Lib\site-packages\pydantic\warnings.py:5
#       1 """Pydantic-specific warnings."""
#       3 from __future__ import annotations as _annotations
# ----> 5 from .version import version_short
#       7 __all__ = (
#       8     'PydanticDeprecatedSince20',
#       9     'PydanticDeprecatedSince26',
#    (...)     18     'TypedDictExtraConfigWarning',
#      19 )
#      22 class PydanticDeprecationWarning(DeprecationWarning):
#
# File e:\Projects\Project1Demo\Langchain_Modules_Learning_Series\.venv\Lib\site-packages\pydantic\version.py:7
#       3 from __future__ import annotations as _annotations
#       5 import sys
# ----> 7 from pydantic_core import __version__ as __pydantic_core_version__
#       9 __all__ = 'VERSION', 'version_info'
#      11 VERSION = '2.13.4'
#
# ImportError: cannot import name '__version__' from 'pydantic_core' (unknown location)

# %%
from langchain_community.tools import DuckDuckGoSearchRun
# Initialize DuckDuckGo Search Tool
search_tool = DuckDuckGoSearchRun()
results = search_tool.run("What is the capital of France?")
print(results)

# %%
from langchain_classic import hub
from langchain.agents import  create_agent
from langchain_classic.agents import AgentExecutor

# Load the agent from the hub

# %%
#Step2 pull the react agent from the hub
prompt = hub.pull("hwcase17/react")

# %%
#Step 3 : create the React Agent Manually with the pulle prompt
agent = create_react_agent(
    llm=llm,
    tools=[search_tool],
    verbose=True
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #Step 3 : create the React Agent Manually with the pulle prompt
# ----> 2 agent = create_react_agent(
#       3     llm=llm,
#       4     tools=[search_tool],
#       5     verbose=True
#       6 )
#
# NameError: name 'create_react_agent' is not defined

# %%
#Step 4: agent Exxecutor wrapping with

# %%
#Step 5 : Invoking
